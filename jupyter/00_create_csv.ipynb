# %%
import pandas as pd

# %%
df_data = pd.read_excel('../data/iso_standard_table_selection.xlsx').fillna(0)
df_data
# Out:
#               title              category                variable_name   type  \
# 0     Personal Data      patientID_basics                         name    str
# 1     Personal Data      patientID_basics                   birth_date    str
# 2     Personal Data      patientID_basics              identity_number    str
# 3     Personal Data      patientID_basics                       adress    obj
# 4     Personal Data      patientID_basics                       gender    int
# 5     Personal Data      patientID_basics              ethnicity_group    str
# 6     Personal Data      patientID_basics             primary_language    str
# 7     Personal Data      patientID_basics                   occupation    str
# 8     Personal Data      patientID_basics                    diagnoses  array
# 9     Personal Data      patientID_basics                   allgergies  array
# 10    Personal Data        emergency_info            emergency_contact    str
# ...
